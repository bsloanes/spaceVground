# %%
#LIBRARIES, TOOLS (still have extras here prob.)
#ABSOLUTE FIRST THING TO RUN 
import numpy as np 
from astropy.io import fits
import matplotlib.pyplot as plt
import array 
import pylab 
import pyphot
from pyphot import Filter
from pyphot import Library
from pyphot import Ascii_Library
import math 
from pyphot import ezunits
import struct
import os
import glob
import itertools 
from itertools import cycle
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import random 
from random import choices 
import re
from astropy.table import Table, Column
import tables
from tables import *
import re 
import heapq
from statistics import *
from matplotlib.backends.backend_pdf import PdfPages
current = os.getcwd() #get current working directory 

#USE FOR SPECTRA
def txtfile(tfilename):

    tdul = np.genfromtxt(tfilename,skip_header = 47)
    wlen = tdul[:,0]
    mag = tdul[:,1]
    wlen = wlen[mag!=-999]
    mag = mag[mag!=-999]
    
    return wlen, mag

#USE FOR FILTERS NOT ALREADY IN PYPHOT
def txtfile2(tfilename):
    tdul = np.genfromtxt(tfilename)
    wlen = tdul[:,0]
    mag = tdul[:,1]
    wlen = wlen[mag!=-999]
    mag = mag[mag!=-999]
    
    return wlen, mag

#USE FOR ALL SPECTRA 
def fitsfile(ffilename):
    hdul = fits.open(ffilename)
    data = fits.getdata(ffilename)
    wave = data[0,:]
    fluxden = data[1,:]
     
    a = float('nan')
    wave = wave[fluxden!=a]
    fluxden = fluxden[fluxden!=a]
    return wave, fluxden

#GETS THE ERROR OUT OF SPECTRA FILE
def spectraError(tfilename):
    tdul = np.genfromtxt(tfilename,skip_header = 47)
    mag = tdul[:,1]
    error = tdul[:,2]
    error = error[mag!=-999]
    
    return error

#DEFINES THE LOWER BOUND OF SPECTRAL FLUX DENSITY
def lowerBound(filename):
    error = spectraError(filename)
    wave, fluxden = txtfile(filename)
    lower = fluxden - error
    return wave, lower 

#DEFINES UPPER BOUND OF SPECTRAL FLUX DENSITY 
def upperBound(filename):
    error = spectraError(filename)
    wave, fluxden = txtfile(filename)
    upper = fluxden + error
    return wave, upper

#SIMULATE A MONTE CARLO ERROR RUN 
#filename needs to be a string, file needs to be an array of strings 
def monteCarlo(file, sampleSize,iterations):
    error = spectraError(file)
    error1 = np.array(error).tolist()
    errora = -1 * error
    error2 = np.array(errora).tolist()
    errorComposite = error1 + error2 
    monteArray = []
    avgArray = []
    for _ in range(0,iterations):
        monteError = np.asarray(random.choices(errorComposite, weights=None, cum_weights=None, k=sampleSize))
        avgErr = np.asarray(float((sum(monteError)) / (len(monteError))))
        print(monteError)
        print(avgErr)
        monteArray.extend(monteError)
        avgArray.append(avgErr)
    return monteArray, avgArray   
    

#OPENS AND READS DATA OF STRINGS AND FLOATS 
#used primarily in here for getting filter names with calculated flux zeropts from SOV 
def datafile(filename):
    f=open(filename,"r")
    lines=f.readlines()
    result=[]
    for x in lines:
        result.append(x.split(' ')[0])
        filters = np.asarray(result)
    f.close()
    
    tdul = np.genfromtxt(filename)
    fluxes = tdul[:,1]
    
    return filters, fluxes

def extendeddatafile(filename):
    f=open(filename,"r")
    lines=f.readlines()
    result=[]
    for x in lines:
        result.append(x.split(' ')[0])
        spectrafits = np.asarray(result)
    f.close()
    
    tdul = np.genfromtxt(filename)
    hmags = tdul[:,1]
    jmags = tdul[:,2]
    ksmags = tdul[:,3]
    
    return spectrafits, hmags, jmags, ksmags

def useFitsdata(filename):
    hdulist = fits.open(filename)
    hdu = hdulist[0]
    return hdu.header['H'], hdu.header['HERR'], hdu.header['J'], hdu.header['JERR'], hdu.header['KS'], hdu.header['KSERR']

# %%
#SECOND SECTION TO RUN 
#get the internal default library of passbands filters
# establishes desired filters as the ones we want to analyze
lib = pyphot.get_library()
print("Library contains: ", len(lib), " filters")
# find all filter names that relates to IRAC
# and print some info
f = lib.find('JWST_NIRCam')
g = lib.find('2MASS')
hi = lib.find('HST_WFC3')
h = hi[0:15]

#test that we see everything is in library 
for name in f:
    lib[name].info(show_zeropoints=True)
# Out:
# Library contains:  243  filters
# Filter object information:
#     name:                 JWST_NIRCAM_F070W
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   0.706178 micrometer
#     pivot wavelength:     0.704322 micrometer
#     effective wavelength: 6955.948963 micrometer
#     norm:                 0.032808
#     definition contains 2050 points
#
#     Zeropoints
#         Vega: 21.933915 mag,
#               1.6843571835368132e-09 erg / angstrom * centimeter ** 2 * second,
#               2.7871200559206776e-05 Jy
#           AB: 21.646804 mag,
#               2.1942116502569344e-09 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701003e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               6.007883234062841e-05 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F090W
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   0.904442 micrometer
#     pivot wavelength:     0.902308 micrometer
#     effective wavelength: 8945.106773 micrometer
#     norm:                 0.061893
#     definition contains 2049 points
#
#     Zeropoints
#         Vega: 22.696077 mag,
#               8.347748748104982e-10 erg / angstrom * centimeter ** 2 * second,
#               2.2670334735419055e-05 Jy
#           AB: 22.184721 mag,
#               1.336938520116417e-09 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701001e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               9.860264467820171e-05 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F115W
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   1.157059 micrometer
#     pivot wavelength:     1.154306 micrometer
#     effective wavelength: 11379.700448 micrometer
#     norm:                 0.088099
#     definition contains 2049 points
#
#     Zeropoints
#         Vega: 23.496777 mag,
#               3.992907853895976e-10 erg / angstrom * centimeter ** 2 * second,
#               1.774640796745417e-05 Jy
#           AB: 22.719553 mag,
#               8.169186796153548e-10 erg / angstrom * centimeter ** 2 * second,
#               3.6307805477010045e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.00016136939593266487 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F140M
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   1.406069 micrometer
#     pivot wavelength:     1.405354 micrometer
#     effective wavelength: 14009.590467 micrometer
#     norm:                 0.060913
#     definition contains 2051 points
#
#     Zeropoints
#         Vega: 24.249942 mag,
#               1.9953694841304932e-10 erg / angstrom * centimeter ** 2 * second,
#               1.3145402244180219e-05 Jy
#           AB: 23.146876 mag,
#               5.511241553421916e-10 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0002391941499529985 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F150W
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   1.504008 micrometer
#     pivot wavelength:     1.500760 micrometer
#     effective wavelength: 14808.806174 micrometer
#     norm:                 0.143678
#     definition contains 2048 points
#
#     Zeropoints
#         Vega: 24.494862 mag,
#               1.5924106199822882e-10 erg / angstrom * centimeter ** 2 * second,
#               1.196346652832789e-05 Jy
#           AB: 23.289505 mag,
#               4.832791139001319e-10 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701005e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0002727733727033803 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F150W2
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   1.703859 micrometer
#     pivot wavelength:     1.658819 micrometer
#     effective wavelength: 13991.447024 micrometer
#     norm:                 0.549146
#     definition contains 2049 points
#
#     Zeropoints
#         Vega: 24.733381 mag,
#               1.278343057295459e-10 erg / angstrom * centimeter ** 2 * second,
#               1.173342820437515e-05 Jy
#           AB: 23.506944 mag,
#               3.9556922536810935e-10 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701021e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0003332556361859699 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F162M
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   1.628063 micrometer
#     pivot wavelength:     1.627256 micrometer
#     effective wavelength: 16227.645914 micrometer
#     norm:                 0.074130
#     definition contains 2051 points
#
#     Zeropoints
#         Vega: 24.816962 mag,
#               1.1836281346484395e-10 erg / angstrom * centimeter ** 2 * second,
#               1.0454576177402044e-05 Jy
#           AB: 23.465228 mag,
#               4.1106343615175675e-10 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701007e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0003206942341789129 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F164N
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   1.644619 micrometer
#     pivot wavelength:     1.644589 micrometer
#     effective wavelength: 16445.857820 micrometer
#     norm:                 0.008627
#     definition contains 2051 points
#
#     Zeropoints
#         Vega: 24.880100 mag,
#               1.1167598995128512e-10 erg / angstrom * centimeter ** 2 * second,
#               1.0075204827224518e-05 Jy
#           AB: 23.488235 mag,
#               4.024444355361814e-10 erg / angstrom * centimeter ** 2 * second,
#               3.630780547700998e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0003275624215800298 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F182M
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   1.846592 micrometer
#     pivot wavelength:     1.845167 micrometer
#     effective wavelength: 18360.334530 micrometer
#     norm:                 0.114408
#     definition contains 2051 points
#
#     Zeropoints
#         Vega: 25.296009 mag,
#               7.613708219939714e-11 erg / angstrom * centimeter ** 2 * second,
#               8.646634287929117e-06 Jy
#           AB: 23.738127 mag,
#               3.1970478662916914e-10 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701006e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.00041233562764434557 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F187N
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   1.873919 micrometer
#     pivot wavelength:     1.873889 micrometer
#     effective wavelength: 18735.528453 micrometer
#     norm:                 0.010750
#     definition contains 2047 points
#
#     Zeropoints
#         Vega: 25.395744 mag,
#               6.945481811157269e-11 erg / angstrom * centimeter ** 2 * second,
#               8.135222324974722e-06 Jy
#           AB: 23.771668 mag,
#               3.099794848500255e-10 erg / angstrom * centimeter ** 2 * second,
#               3.6307805477009984e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.00042527225283769916 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F200W
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   1.993388 micrometer
#     pivot wavelength:     1.988642 micrometer
#     effective wavelength: 19587.019603 micrometer
#     norm:                 0.225358
#     definition contains 2048 points
#     Zeropoints
#         Vega: 25.576696 mag,
#               5.87924419314393e-11 erg / angstrom * centimeter ** 2 * second,
#               7.75557750674071e-06 Jy
#           AB: 23.900732 mag,
#               2.752373428425939e-10 erg / angstrom * centimeter ** 2 * second,
#               3.6307805477009964e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.00047895271947538676 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F210M
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   2.096373 micrometer
#     pivot wavelength:     2.095448 micrometer
#     effective wavelength: 20889.980268 micrometer
#     norm:                 0.100208
#     definition contains 2051 points
#
#     Zeropoints
#         Vega: 25.794669 mag,
#               4.809858937988457e-11 erg / angstrom * centimeter ** 2 * second,
#               7.044746817167277e-06 Jy
#           AB: 24.014333 mag,
#               2.4789453364991845e-10 erg / angstrom * centimeter ** 2 * second,
#               3.6307805477010025e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0005317812858342683 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F212N
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   2.121250 micrometer
#     pivot wavelength:     2.121191 micrometer
#     effective wavelength: 21204.110745 micrometer
#     norm:                 0.013268
#     definition contains 2049 points
#
#     Zeropoints
#         Vega: 25.841899 mag,
#               4.6051131721500184e-11 erg / angstrom * centimeter ** 2 * second,
#               6.911608008280037e-06 Jy
#           AB: 24.040847 mag,
#               2.4191411470924537e-10 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701005e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0005449275831386699 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F250M
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   2.504112 micrometer
#     pivot wavelength:     2.503482 micrometer
#     effective wavelength: 24995.103161 micrometer
#     norm:                 0.071815
#     definition contains 2535 points
#
#     Zeropoints
#         Vega: 26.517150 mag,
#               2.4725201747803986e-11 erg / angstrom * centimeter ** 2 * second,
#               5.169018997352128e-06 Jy
#           AB: 24.400671 mag,
#               1.7367276380662526e-10 erg / angstrom * centimeter ** 2 * second,
#               3.6307805477010004e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0007590463292357128 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F277W
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   2.769490 micrometer
#     pivot wavelength:     2.761872 micrometer
#     effective wavelength: 27131.777480 micrometer
#     norm:                 0.280904
#     definition contains 2535 points
#
#     Zeropoints
#         Vega: 26.903135 mag,
#               1.7327910189532542e-11 erg / angstrom * centimeter ** 2 * second,
#               4.4089240657800926e-06 Jy
#           AB: 24.613966 mag,
#               1.4269658154643897e-10 erg / angstrom * centimeter ** 2 * second,
#               3.630780547700996e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0009238180230178711 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F300M
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   2.990913 micrometer
#     pivot wavelength:     2.989254 micrometer
#     effective wavelength: 29786.368785 micrometer
#     norm:                 0.123731
#     definition contains 2236 points
#
#     Zeropoints
#         Vega: 27.238947 mag,
#               1.2718067761460744e-11 erg / angstrom * centimeter ** 2 * second,
#               3.790757049909402e-06 Jy
#           AB: 24.785762 mag,
#               1.2181343310766503e-10 erg / angstrom * centimeter ** 2 * second,
#               3.6307805477009984e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.001082193240043776 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F322W2
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   3.266804 micrometer
#     pivot wavelength:     3.232002 micrometer
#     effective wavelength: 30073.766259 micrometer
#     norm:                 0.710104
#     definition contains 2236 points
#
#     Zeropoints
#         Vega: 27.488313 mag,
#               1.010822133659533e-11 erg / angstrom * centimeter ** 2 * second,
#               3.5220634020073918e-06 Jy
#           AB: 24.955306 mag,
#               1.0420236438631128e-10 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701001e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0012650929240618784 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F323N
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   3.236957 micrometer
#     pivot wavelength:     3.236919 micrometer
#     effective wavelength: 32366.624405 micrometer
#     norm:                 0.012261
#     definition contains 2236 points
#
#     Zeropoints
#         Vega: 27.564835 mag,
#               9.420323768616001e-12 erg / angstrom * centimeter ** 2 * second,
#               3.2923716184385557e-06 Jy
#           AB: 24.958608 mag,
#               1.038859893597238e-10 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701009e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.001268945645780686 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F335M
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   3.364007 micrometer
#     pivot wavelength:     3.362173 micrometer
#     effective wavelength: 33502.183788 micrometer
#     norm:                 0.160690
#     definition contains 2236 points
#
#     Zeropoints
#         Vega: 27.722859 mag,
#               8.144346564666522e-12 erg / angstrom * centimeter ** 2 * second,
#               3.0709700582990165e-06 Jy
#           AB: 25.041048 mag,
#               9.628988404108829e-11 erg / angstrom * centimeter ** 2 * second,
#               3.6307805477009964e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0013690500842164042 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F356W
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   3.576812 micrometer
#     pivot wavelength:     3.568382 micrometer
#     effective wavelength: 35119.188148 micrometer
#     norm:                 0.407951
#     definition contains 2157 points
#
#     Zeropoints
#         Vega: 27.957159 mag,
#               6.563513991812437e-12 erg / angstrom * centimeter ** 2 * second,
#               2.7877787815816603e-06 Jy
#           AB: 25.170305 mag,
#               8.54826756107079e-11 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701003e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0015421332207239305 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F360M
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   3.626123 micrometer
#     pivot wavelength:     3.624229 micrometer
#     effective wavelength: 36110.477691 micrometer
#     norm:                 0.186015
#     definition contains 2236 points
#
#     Zeropoints
#         Vega: 28.035685 mag,
#               6.105569114365547e-12 erg / angstrom * centimeter ** 2 * second,
#               2.6750790863057884e-06 Jy
#           AB: 25.204026 mag,
#               8.286850914638123e-11 erg / angstrom * centimeter ** 2 * second,
#               3.630780547700998e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0015907812897029343 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F405N
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   4.051757 micrometer
#     pivot wavelength:     4.051723 micrometer
#     effective wavelength: 40515.653331 micrometer
#     norm:                 0.019240
#     definition contains 2238 points
#
#     Zeropoints
#         Vega: 28.527678 mag,
#               3.880868351729787e-12 erg / angstrom * centimeter ** 2 * second,
#               2.1251409927977664e-06 Jy
#           AB: 25.446147 mag,
#               6.630421871961828e-11 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701007e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.001988194362308882 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F410M
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   4.084380 micrometer
#     pivot wavelength:     4.082233 micrometer
#     effective wavelength: 40679.662332 micrometer
#     norm:                 0.219294
#     definition contains 2236 points
#
#     Zeropoints
#         Vega: 28.534824 mag,
#               3.8554081725847035e-12 erg / angstrom * centimeter ** 2 * second,
#               2.1431143368835597e-06 Jy
#           AB: 25.462437 mag,
#               6.531681840560874e-11 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701001e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0020182500782114036 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F430M
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   4.281770 micrometer
#     pivot wavelength:     4.281198 micrometer
#     effective wavelength: 42771.725853 micrometer
#     norm:                 0.113941
#     definition contains 2157 points
#
#     Zeropoints
#         Vega: 28.736414 mag,
#               3.2020950619056152e-12 erg / angstrom * centimeter ** 2 * second,
#               1.957691046091472e-06 Jy
#           AB: 25.565775 mag,
#               5.938681941600461e-11 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701001e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.002219779997514283 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F444W
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   4.415860 micrometer
#     pivot wavelength:     4.404160 micrometer
#     effective wavelength: 43272.378280 micrometer
#     norm:                 0.530834
#     definition contains 2236 points
#
#     Zeropoints
#         Vega: 28.835804 mag,
#               2.9219890347602506e-12 erg / angstrom * centimeter ** 2 * second,
#               1.890532331793693e-06 Jy
#           AB: 25.627264 mag,
#               5.611700349994804e-11 erg / angstrom * centimeter ** 2 * second,
#               3.6307805477010065e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.002349121756933478 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F460M
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   4.630239 micrometer
#     pivot wavelength:     4.629629 micrometer
#     effective wavelength: 46243.468547 micrometer
#     norm:                 0.097433
#     definition contains 2236 points
#     Zeropoints
#         Vega: 29.068781 mag,
#               2.3576946033231957e-12 erg / angstrom * centimeter ** 2 * second,
#               1.6856182850656027e-06 Jy
#           AB: 25.735679 mag,
#               5.078416495008732e-11 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701001e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0025958027267988628 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F466N
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   4.654441 micrometer
#     pivot wavelength:     4.654405 micrometer
#     effective wavelength: 46539.235479 micrometer
#     norm:                 0.017661
#     definition contains 2236 points
#
#     Zeropoints
#         Vega: 29.123266 mag,
#               2.2422991868707064e-12 erg / angstrom * centimeter ** 2 * second,
#               1.6203217913647988e-06 Jy
#           AB: 25.747269 mag,
#               5.024493476051154e-11 erg / angstrom * centimeter ** 2 * second,
#               3.630780547701009e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.002623660961726325 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F470N
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   4.707772 micrometer
#     pivot wavelength:     4.707737 micrometer
#     effective wavelength: 47076.316929 micrometer
#     norm:                 0.015536
#     definition contains 2238 points
#
#     Zeropoints
#         Vega: 29.136270 mag,
#               2.2156037222703768e-12 erg / angstrom * centimeter ** 2 * second,
#               1.6379319551382322e-06 Jy
#           AB: 25.772009 mag,
#               4.911297365557734e-11 erg / angstrom * centimeter ** 2 * second,
#               3.6307805477010065e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0026841313820685293 Jy
#
# Filter object information:
#     name:                 JWST_NIRCAM_F480M
#     detector type:        photon
#     wavelength units:     um
#     central wavelength:   4.818972 micrometer
#     pivot wavelength:     4.817826 micrometer
#     effective wavelength: 48091.062936 micrometer
#     norm:                 0.122696
#     definition contains 2236 points
#
#     Zeropoints
#         Vega: 29.229727 mag,
#               2.032868044032307e-12 erg / angstrom * centimeter ** 2 * second,
#               1.57394936026712e-06 Jy
#           AB: 25.822204 mag,
#               4.6894124656353865e-11 erg / angstrom * centimeter ** 2 * second,
#               3.630780547700997e-05 Jy
#           ST: 21.100000 mag,
#               3.6307805477010028e-09 erg / angstrom * centimeter ** 2 * second,
#               0.0028111341201413845 Jy

# %%
#THIRD TO RUN 
#sets up all of the filters we want to use in the same set from the default internal library 
theseFilters = g+h #perhaps split this up so that we can compare 2mass stuff to everything else
i = lib[theseFilters]
twomass = lib[g]
hst = lib[h]
jwst = lib[f]

# %%
#FOURTH TO RUN 
#sets up our database of spectral files we are using (from working in the directory I set up of them)
file = os.listdir(current) #determines how many files we need to go through
thisFile = glob.glob("*star.txt")#change end of names of files (make this call easier) 
tFarray = np.asarray(thisFile)#converts to array for indexing 
fitsfiles = glob.glob("*.fits")
fitsarray = np.asarray(fitsfiles)
GKM = tFarray[15:]
Fstars = tFarray[0:15]
Gstars = tFarray[15:38]
Kstars = tFarray[38:64]
Mstars = tFarray[64:]
GKMstars = [Gstars, Kstars, Mstars]
FGKMstars = [Fstars, Gstars, Kstars, Mstars]
FGKstars = [Fstars, Gstars, Kstars]
print(len(GKMstars))
# Out:
# 3

# %%
print(Mstars[0])
# Out:
# M0IIIb_HD213893star.txt

# %%
#data directly from the files on calculated magnitudes and error for H, J and Ks, respectively 
def firstError(fits):
    for fit in range(0,len(fits)):
        
        
        a, b, c, d, e, f = useFitsdata(fits[fit])
        print(fits[fit] + '  ' + str(a) + '  '  + str(c) + '  ' + str(e))
        #print('upper and lower bounds : ' + str(a+b) + ' , ' + str(a-b) + ' , ' + str(c+d) + ' , ' + str(c-d) + ' , '
             # + str(e+f) + ' , ' + str(e-f))
        #return a, b, c, d, e, f, a+b, a-b, c+d, c-d, e+f, e-f

# %%
firstError(fitsarray)

# %%
#gets the fitserror data into something interpretable 
spe, hma, jma, ksma = extendeddatafile('rawData.txt')
hma = np.array(hma).tolist()
jma = np.array(jma).tolist()
ksma = np.array(ksma).tolist()

# %%
#FIFTH TO RUN 
#the only two filters not in the pyphot module
#ran into an error where I accidentally erased the pyphot filters when I tried to add them, so I'm just working with these two separately
#also set up a short array so that we can loop through these as well 
w, fill = txtfile2('HST_WFC3_G102.txt') 
HST_WFC3_G102 = Filter(w, fill, name='HST_WFC3_G102', dtype="photon", unit='Angstrom')

w2, f2 = txtfile2('HST_WFC3_G141.txt')
HST_WFC3_G141 = Filter(w2, f2, name= 'HST_WFC3_G141', dtype="photon", unit='Angstrom')

newFilters = HST_WFC3_G102.name + HST_WFC3_G141.name
newFiltersarray = np.asarray(newFilters)

j1, j2 = txtfile2('2MASS_J.txt')
twoMass_J = Filter(j1,j2, name= '2MASS_J1', dtype="photon", unit='Angstrom')
newJ = [twoMass_J]

# %%
colors(twoMass_J,twomass[0], magnitudeCalc, [hstForh[2]], magnitudeCalc, hstForj[0], magnitudeCalc, 9)
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# F stars 2MASS_J1 - HST_WFC3_F160W 2MASS_J1 - 2MASS_H color fit = [-0.12547315 -0.03774376]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# G stars 2MASS_J1 - HST_WFC3_F160W 2MASS_J1 - 2MASS_H color fit = [-0.03732835 -0.06638569]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# K stars 2MASS_J1 - HST_WFC3_F160W 2MASS_J1 - 2MASS_H color fit = [ 0.02621191 -0.09532609]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# M stars 2MASS_J1 - HST_WFC3_F160W 2MASS_J1 - 2MASS_H color fit = [ 0.04575276 -0.10949046]
#
# all spectra 2MASS_J1 - HST_WFC3_F160W2MASS_J1 - 2MASS_H color fit = [-0.01512862 -0.06921083]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, **kwargs)
#    2579         try:
# -> 2580             file.newPage(width, height)
#    2581             _bbox_inches_restore = kwargs.pop("bbox_inches_restore", None)
#
# AttributeError: 'NoneType' object has no attribute 'newPage'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-24672cb1177e> in <module>()
# ----> 1 colors(twoMass_J,twomass[0], magnitudeCalc, [hstForh[2]], magnitudeCalc, hstForj[0], magnitudeCalc, 9)
#
# <ipython-input-38-174f394b26c0> in colors(twoMass, twoMass2, magFuncHst_Jwst0, Hst_Jwst, magFuncHst_Jwst, twoMass3, magFuncHst_Jwst2, location)
#      89         plt.legend(loc=location, bbox_to_anchor=(0.5, 1), ncol=3)
#      90
# ---> 91         pdfgraphic.savefig()
#      92         plt.show()
#      93
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_pdf.py in savefig(self, figure, **kwargs)
#    2527             orig_canvas = figure.canvas
#    2528             figure.canvas = FigureCanvasPdf(figure)
# -> 2529             figure.savefig(self, format="pdf", **kwargs)
#    2530         finally:
#    2531             figure.canvas = orig_canvas
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, **kwargs)
#    2590         finally:
#    2591             if isinstance(filename, PdfPages):  # finish off this page
# -> 2592                 file.endStream()
#    2593             else:            # we opened the file above; now finish it off
#    2594                 file.close()
#
# AttributeError: 'NoneType' object has no attribute 'endStream'

# %%
mag_mag_delta(magnitudeCalc,[hstForj[0]],twoMass_J)
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# F stars 2MASS_J1 HST_WFC3_F110W mag-mag slope, intercept = [1.00168817 0.09467522]
# F stars 2MASS_J1 mag-delta slope, intercept = [-0.00168817 -0.09467522]
# F stars HST_WFC3_F110W mag-delta slope, intercept = [-0.0020205  -0.09295974]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# G stars 2MASS_J1 HST_WFC3_F110W mag-mag slope, intercept = [0.99649848 0.1899114 ]
# G stars 2MASS_J1 mag-delta slope, intercept = [ 0.00350152 -0.1899114 ]
# G stars HST_WFC3_F110W mag-delta slope, intercept = [ 0.00284937 -0.18754048]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# K stars 2MASS_J1 HST_WFC3_F110W mag-mag slope, intercept = [1.00161715 0.22712864]
# K stars 2MASS_J1 mag-delta slope, intercept = [-0.00161715 -0.22712864]
# K stars HST_WFC3_F110W mag-delta slope, intercept = [-0.00186115 -0.22589154]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# M stars 2MASS_J1 HST_WFC3_F110W mag-mag slope, intercept = [1.02259535 0.31047939]
# M stars 2MASS_J1 mag-delta slope, intercept = [-0.02259535 -0.31047939]
# M stars HST_WFC3_F110W mag-delta slope, intercept = [-0.02313947 -0.30066099]
#
# all spectra 2MASS_J1 HST_WFC3_F110W mag-mag slope, intercept = [0.99020718 0.22015192]
# all spectra 2MASS_J1 mag-delta slope, intercept = [ 0.00979282 -0.22015192]
# all spectra HST_WFC3_F110W mag-delta slope, intercept = [ 0.00862507 -0.21706197]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, **kwargs)
#    2579         try:
# -> 2580             file.newPage(width, height)
#    2581             _bbox_inches_restore = kwargs.pop("bbox_inches_restore", None)
#
# AttributeError: 'NoneType' object has no attribute 'newPage'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-c92deeeef9ae> in <module>()
# ----> 1 mag_mag_delta(magnitudeCalc,[hstForj[0]],twoMass_J)
#
# <ipython-input-26-1adc522569d5> in mag_mag_delta(magFuncHst_Jwst, Hst_Jwst, twoMass)
#     112         #creates the figure for ea. hst/jwst filter, across G,K,M stars for specified 2mass filter
#     113         #moves on to next hst/jwst filter only when this set is done
# --> 114         pdfgraphing.savefig()
#     115         plt.show()
#     116
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_pdf.py in savefig(self, figure, **kwargs)
#    2527             orig_canvas = figure.canvas
#    2528             figure.canvas = FigureCanvasPdf(figure)
# -> 2529             figure.savefig(self, format="pdf", **kwargs)
#    2530         finally:
#    2531             figure.canvas = orig_canvas
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    2033             self.set_frameon(frameon)
#    2034
# -> 2035         self.canvas.print_figure(fname, **kwargs)
#    2036
#    2037         if frameon:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2261                 orientation=orientation,
#    2262                 bbox_inches_restore=_bbox_inches_restore,
# -> 2263                 **kwargs)
#    2264         finally:
#    2265             if bbox_inches and restore_bbox:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_pdf.py in print_pdf(self, filename, **kwargs)
#    2590         finally:
#    2591             if isinstance(filename, PdfPages):  # finish off this page
# -> 2592                 file.endStream()
#    2593             else:            # we opened the file above; now finish it off
#    2594                 file.close()
#
# AttributeError: 'NoneType' object has no attribute 'endStream'

# %%
def central_wavelengths(filterlibrary): 
    cl = []
    cln = []
    for cllen in range(0,len(filterlibrary)):
        center = filterlibrary[cllen].cl.magnitude
        centername = filterlibrary[cllen].name
        cl.append(center)
        cln.append(centername)
    return cl, cln

def central_wavelengths_jwst(filterlibrary):
    cl = []
    cln = []
    for cllen in range(0,len(filterlibrary)):
        center = filterlibrary[cllen].cl.magnitude
        center = center * 10e3
        centername = filterlibrary[cllen].name
        cl.append(center)
        cln.append(centername)
    return cl, cln

# %%
#compare hst and jwst to h and j, and compare jwst to ks 
clh, clnh = central_wavelengths(twomass)
clhst, clnhst = central_wavelengths(hst)
cljwst, clnjwst = central_wavelengths_jwst(jwst)

# %%
def findCloseFilt(filterlibrary, function):
    char = "(\d+)([N])"
    cl2, cln2 = central_wavelengths(twomass)
    cl, cln = function(filterlibrary)
    for tm in range(0,len(cl2)): 
        diffArray = abs(cl2[tm]-cl)
        for dif in range(0,len(diffArray)):
            if (diffArray[dif] < 1.25 * 10e2):
                #print(str(cln[dif]) + ' is compatible with ' + str(cln2[tm])) 
                if re.search(char,cln[dif]):
                    print('',end="")
                else: 
                    print(str(cln[dif]) + ' is compatible with ' + str(cln2[tm]))

# %%
print((findCloseFilt(hst,central_wavelengths)))#2MASS TO HST
print((findCloseFilt(jwst,central_wavelengths_jwst))) #2MASS TO JWST

#ignore filters that have N in them 
#can calculate numerically by subtracting first nonzero element and last: less than 300A eliminate 
#above: used character-searching since pyphot does not already have the min & max
# Out:
# HST_WFC3_F127M is compatible with 2MASS_H
# HST_WFC3_F153M is compatible with 2MASS_H
# HST_WFC3_F160W is compatible with 2MASS_H
# HST_WFC3_F110W is compatible with 2MASS_J
# HST_WFC3_F125W is compatible with 2MASS_J
# None
# JWST_NIRCAM_F150W2 is compatible with 2MASS_H
# JWST_NIRCAM_F162M is compatible with 2MASS_H
# JWST_NIRCAM_F115W is compatible with 2MASS_J
# JWST_NIRCAM_F210M is compatible with 2MASS_Ks
# None

# %%
#non-narrow-band filters 
hstForh = [hst[5],hst[11],hst[12]]
hstForj = [hst[2],hst[3]]
jwstForh = [jwst[5],jwst[6]]
jwstForj = [jwst[2]]
jwstForks = [jwst[11]]
composite = [hst[2],hst[3],hst[5],hst[11],hst[12],jwst[2],jwst[5],
            jwst[6],jwst[11],jwst[12],twomass[0],twomass[1],twomass[2]]

Forj = [hst[2],hst[3],jwst[2]]
Forh = [hst[5],hst[11],hst[12],jwst[5],jwst[6]]
#composite will be used to simulate monte-carlo. otherwise, mag_mag will call for the smaller arrays to use w/ 
#appropriate 2mass filter in plotting

# %%
aa, bb = txtfile(Fstars[0])
print(len(bb))
# Out:
# 6673

# %%
#reference for magnitdes in 2mass filters, to compare to the IRTF data
for this in range(0,len(twomass)):
    for that in range(0,len(GKMstars)):
        magCalc(twomass[this],GKMstars[that])

# %%
#CALCULATES MAGNITUDES (magnitudeCalc for 2mass, hst and magnitudecalc2 for jwst)
def magnitudeCalc(filter,spectra):
    magnitudes = []
    for x in range(0,int(len(spectra))):
        
        w, f = txtfile(spectra[x]) #gets all of the data we need for ea. file [x]
        w = w * 10e3 #standardized to A
        f = f * 10e-2 #standardized to A^(-1)
        fluxes = filter.get_flux(w, f, axis=-1) #for some reason, using fits file data produces nan 
        RegMags = -2.5 * np.log10(fluxes) - filter.Vega_zero_mag
        magnitudes.append(RegMags)
    return magnitudes 

def magnitudeCalc2(filter,spectra):
    magnitudes = []
    for x in range(0,int(len(spectra))):
        
        w, f = txtfile(spectra[x]) #gets all of the data we need for ea. file [x]
        fluxes = filter.get_flux(w, f, axis=-1) #for some reason, using fits file data produces nan 
        RegMags = -2.5 * np.log10(fluxes) - filter.Vega_zero_mag
        magnitudes.append(RegMags)
    return magnitudes

# %%
#simpler to print
charac = 'JWST'
def easierCalc(filter, spectra):
    for gg in range(0,len(spectra)):
        wave, flux = txtfile(spectra[gg])
        if re.search(charac,filter.name):
            wave = wave
            flux = flux 

        else:
            wave = wave * 10e3 #standardized to A
            flux = flux * 10e-2 #standardized to A^(-1)

        fluxes = filter.get_flux(wave, flux, axis=-1) #for some reason, using fits file data produces nan
        RegMags = -2.5 * np.log10(fluxes) - filter.Vega_zero_mag
        
        print(RegMags)
        for sp in range(0,3):
            print('')

# %%
easierCalc(twomass[2],tFarray)

# %%
#magFuncHst_Jwst = magnitudeCalc for HST, magnitudeCalc2 for JWST
#Hst_Jwst = any of the arrays I set up to correspond to the twoMass arrays
#twoMass = either twomass[0](h), twomass[1](j), or twomass[2](ks)
#maybe put errors that pop up when I try an incorrect combination of any of the three above
markers = ['o', 'p', 's', '*']
markercycle = cycle(markers)
size = [240,170,100,30]
sizecycle = cycle(size)
color = 'mcbr'

# %%
#F160W = hstForh[2], F110W = hstForj[0]
#modified version of color method, except takes in input arguments for four filters and plots accordingly

# %%
pdfgraphs = PdfPages('mag_color_BSS_colorDeltacolor.pdf')

# %%
def colors(twoMass, twoMass2, magFuncHst_Jwst0, Hst_Jwst, magFuncHst_Jwst, twoMass3, magFuncHst_Jwst2, location):
    FGKM = ['F stars','G stars','K stars','M stars']
    
    for theseFilt in range(0,len(Hst_Jwst)):
        
        #amasses all magnitudes across G,K,M-type stars for ea. type of filter
        mtmass = []
        mt2mass = []
        mhmass = []
        mdmass = []
        md2mass = []
        twodmass = []    
        ultramass = []
            
        for theseStars in range(0,len(FGKMstars)):
            #initializes arrays used in calculating magnitude, will iterate for F, G, K separately 
            mt = []
            mt2 = []
            mh = []
            md = []
            md2 = []
            twod = []
            ultra = []
            
            #magnitude calculation for ea. filter and calculating the difference
            magnitwo = magnitudeCalc(twoMass,FGKMstars[theseStars])
            magnitwo2 = magFuncHst_Jwst0(twoMass2, FGKMstars[theseStars])
            magnihst = magFuncHst_Jwst(Hst_Jwst[theseFilt],FGKMstars[theseStars])
            magnitwo3 = magFuncHst_Jwst2(twoMass3,FGKMstars[theseStars])
                
            #magnidiff1 = [magnitwo - magnitwo3 for magnitwo, magnitwo3 in zip(magnitwo,magnitwo3)] 
            magnidiff1 = [magnitwo3 - magnihst for magnitwo3, magnihst in zip(magnitwo3,magnihst)] 
            twoDiff = [magnitwo - magnitwo2 for magnitwo, magnitwo2 in zip(magnitwo,magnitwo2)]
            #magnidiff2 = [magnitwo2 - magnihst for magnitwo2, magnihst in zip(magnitwo2,magnihst)]
            ultraDiff =  [twoDiff - magnidiff1 for twoDiff, magnidiff1 in zip(twoDiff,magnidiff1)]
            #ultraDiff = [magnidiff1 - magnidiff2 for magnidiff1,magnidiff2 in zip(magnidiff1,magnidiff2)]
            
            
            #for ea. class of star
            mt.append(magnitwo)
            mt2.append(magnitwo2)
            mh.append(magnihst)
            md.append(magnidiff1)
            #md2.append(magnidiff2)
            twod.append(twoDiff)
            ultra.append(ultraDiff)
            
            #format needed to analyze linear model 
            mda = np.asarray(md[0])
            tda = np.asarray(twod[0])
            uda = np.asarray(ultra[0])
            
            #linear regression in ea. type of filter and diff for ea. class of star
            #regsth = np.polyfit(tda,mda,1)
            regsth = np.polyfit(tda,uda,1)
            
            #printing ea. linear regression of mag-mag and both delta-mag-mag functions, for ea. class of star 
            print(str(FGKM[theseStars]) + ' ' + str(twoMass.name) + ' - ' + str(Hst_Jwst[theseFilt].name) + ' ' + str(twoMass.name) + ' - ' + str(twoMass2.name) + ' color fit = ' + str(regsth))
  
            #iterates so that the markers between F,G,K,M on ea. graph are diff. Othe graph properties 
            #plt.scatter(twod, md, s=size[theseStars], marker = markers[theseStars], c=color[theseStars],alpha = 0.23, label=FGKM[theseStars])
            plt.scatter(twod,ultra,s=size[theseStars], marker = markers[theseStars], c=color[theseStars],alpha = 0.23, label=FGKM[theseStars])
            
            #masses all magnitudes and diff calculations across F,G,K,M stars
            if(theseStars !=3):    
                twodmass.extend(twoDiff)
                mdmass.extend(magnidiff1)
                ultramass.extend(ultraDiff)
                
        #fitting = np.polyfit(np.asarray(twodmass),np.asarray(mdmass),1)
        fitting = np.polyfit(np.asarray(twodmass),np.asarray(ultramass),1)
        #plt.plot(np.unique(twodmass), np.poly1d(np.polyfit(np.asarray(twodmass),np.asarray(mdmass),1))(np.unique(twodmass)), label='y=' + str("%.4f" % fitting[0]) + '*x' + ' + ' + str("%.4f" % fitting[1]))
        plt.plot(np.unique(twodmass), np.poly1d(np.polyfit(np.asarray(twodmass),np.asarray(ultramass),1))(np.unique(twodmass)), label='y=' + str("%.4f" % fitting[0]) + '*x' + ' + ' + str("%.4f" % fitting[1]))
        zcolor = np.zeros(len(twodmass))
        zcolor = zcolor + fitting[1]
        plt.plot(twodmass,zcolor,label='y = '  + str("%.4f" % fitting[1]))
        
        #linear regression for entire graph
        print('')
        print('all spectra ' + str(twoMass.name) +  ' - ' + str(Hst_Jwst[theseFilt].name) + str(twoMass.name) + ' - ' + str(twoMass2.name) + ' color fit = ' + str(fitting))
        
        #sets limits so we can see what's going on 
        #plt.ylim((min(mdmass)-0.1),(max(mdmass)+0.1))
        plt.ylim((min(ultramass)-0.025),(max(ultramass)+0.025))
        plt.xlim((min(twodmass)-0.025),(max(twodmass)+0.025)) 
        plt.xlabel('(' +str(twoMass.name) + ' - ' + str(twoMass2.name) + ')', fontsize=9)
        #plt.ylabel(str(twoMass3.name) + ' - ' + str(Hst_Jwst[theseFilt].name), fontsize=9)
        plt.ylabel('(' + str(twoMass.name) + ' - ' + str(twoMass2.name) + ') ' + ' - ' + ' (' + str(twoMass3.name) + ' - ' + str(Hst_Jwst[theseFilt].name) + ')', fontsize=9)
        plt.legend(loc=location, bbox_to_anchor=(0.5, 1), ncol=3)
        
        pdfgraphic.savefig()
        plt.show()

# %%
#NEW GOOD CALLS:
#J-'Jx'
#H-'Hx'
#Ks-'Ks'
#magnitwo = magnitwo3
#magnitwo2, magnihst will be used for hst/jwst filters interchangeably 
pdfgraphic = PdfPages('newGraphs3.pdf')
colors(twomass[1], twomass[0], magnitudeCalc, [hstForh[2]], magnitudeCalc, hstForj[0], magnitudeCalc, 9)
pdfgraphic.close()
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# F stars 2MASS_J - HST_WFC3_F160W 2MASS_J - 2MASS_H color fit = [-0.12459608 -0.03786761]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# G stars 2MASS_J - HST_WFC3_F160W 2MASS_J - 2MASS_H color fit = [-0.03628203 -0.06656247]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# K stars 2MASS_J - HST_WFC3_F160W 2MASS_J - 2MASS_H color fit = [ 0.02693584 -0.09535395]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# M stars 2MASS_J - HST_WFC3_F160W 2MASS_J - 2MASS_H color fit = [ 0.04635579 -0.10952544]
#
# all spectra 2MASS_J - HST_WFC3_F160W2MASS_J - 2MASS_H color fit = [-0.01424182 -0.06933076]

# %%
#J-'Jx'

for hj in range(0,len(hstForj)):
    colors(twomass[1], hstForj[hj], magnitudeCalc, hstForj, magnitudeCalc, twomass[1], magnitudeCalc, 9)
    colors(twomass[1], hstForj[hj], magnitudeCalc, jwstForj, magnitudeCalc2, twomass[1], magnitudeCalc, 9) 
    
for hj in range(0,len(jwstForj)):
    colors(twomass[1], jwstForj[hj], magnitudeCalc2, jwstForj, magnitudeCalc2, twomass[1], magnitudeCalc, 9) 
    colors(twomass[1], jwstForj[hj], magnitudeCalc2, hstForj, magnitudeCalc, twomass[1], magnitudeCalc, 9)

# %%
#H-'Hx'
for hj in range(0,len(hstForh)):
    colors(twomass[0], hstForh[hj], magnitudeCalc, hstForh, magnitudeCalc, twomass[0], magnitudeCalc, 9)
    colors(twomass[0], hstForh[hj], magnitudeCalc, jwstForh, magnitudeCalc2, twomass[0], magnitudeCalc, 9) 
    
for hj in range(0,len(jwstForj)):
    colors(twomass[0], jwstForh[hj], magnitudeCalc2, jwstForh, magnitudeCalc2, twomass[0], magnitudeCalc, 9) 
    colors(twomass[0], jwstForh[hj], magnitudeCalc2, hstForh, magnitudeCalc, twomass[0], magnitudeCalc, 9)

# %%
#K-'Kx'
for hj in range(0,len(jwstForj)):
    colors(twomass[2], jwstForks[hj], magnitudeCalc2, jwstForks, magnitudeCalc2, twomass[2], magnitudeCalc, 9)

# %%
#For H, do w/ Ks, but perhaps come back to this another time 
for hj in range(0,len(hstForj)):
    colors(twomass[1], twomass[0], magnitudeCalc, hstForh, magnitudeCalc, hstForj[hj], magnitudeCalc, 9)
    colors(twomass[1], twomass[0], magnitudeCalc, jwstForh, magnitudeCalc2, hstForj[hj], magnitudeCalc, 9)
    
for hj in range(0,len(jwstForj)):
    colors(twomass[1], twomass[0], magnitudeCalc, hstForh, magnitudeCalc, jwstForj[hj], magnitudeCalc2, 9)
    colors(twomass[1], twomass[0], magnitudeCalc, jwstForh, magnitudeCalc2, jwstForj[hj], magnitudeCalc2, 9)

# %%
#filter combos: J-H with j-j-like and h-h-like, J-K with j-j-like and k-k-like

tm_withoutJ = [twomass[0],twomass[2]]
tm_withoutH = [twomass[1],twomass[2]]
tm_withoutKs = [twomass[0],twomass[1]]

# %%
HLike = [hstForh[2]]
print(hstForj)

# %%
#colors(twomass[1],twomass[0],HLike,magnitudeCalc,hstForj[0],magnitudeCalc,9)#Dalcanton

# %%
#subtracted y-instance calls                               DONE?                                       Ignore for Now?
# J-'H': hst and jwst                                       yes                                             no
#'J'-H: hst and jwst                                        yes                                             no
#'J'-'H':hst-hst, hst-jwst, jwst-hst, jwst-jwst             yes                                             yes
#'J'-Ks: hst and jwst                                       yes                                             no
# J-'Ks': hst and jwst                                      yes, dne in hst                                 no
#'J'-'Ks': hst-hst, hst-jwst, jwst-hst, jwst-jwst           yes, dne in hst-hst, jwst-hst                   yes

# %%
#ALL POSSIBLE CALLS FOR colors method with color vs delta-color. Look back to prev. copies for other types of graphs
#LEAVE FOR NOW; add magFuncalc as magnitudeCalc

#COMPARE TO H
colors(twomass[1], twomass[0], hstForh, magnitudeCalc, twomass[1], magnitudeCalc, 9) #(J-'H') hst
colors(twomass[1], twomass[0], jwstForh, magnitudeCalc2, twomass[1], magnitudeCalc, 9) #(J-'H') jwst

for hj in range(0,len(hstForj)):
    colors(twomass[1], twomass[0], [twomass[0]], magnitudeCalc, hstForj[hj], magnitudeCalc, 9) #('J'-H) hst
    #colors(twomass[1], twomass[0], hstForh, magnitudeCalc, hstForj[hj], magnitudeCalc, 9) #('J'-'H') hst-hst
    #colors(twomass[1], twomass[0], jwstForh, magnitudeCalc, hstForj[hj], magnitudeCalc, 9) #('J'-'H') jwst-hst

for hj in range(0,len(jwstForj)):
    colors(twomass[1], twomass[0], [twomass[0]], magnitudeCalc, jwstForj[hj], magnitudeCalc2, 9) #('J'-H) jwst
    #colors(twomass[1], twomass[0], hstForh, magnitudeCalc, jwstForh[hj], magnitudeCalc2, 9) #('J'-'H') hst-jwst
    #colors(twomass[1], twomass[0], jwstForh, magnitudeCalc2, jwstForh[hj], magnitudeCalc2, 9) #('J'-'H') jwst-jwst

#COMPARE TO Ks
colors(twomass[1], twomass[2], jwstForks, magnitudeCalc2, twomass[1], magnitudeCalc, 9)#(J-'Ks') jwst 

for hj in range(0,len(jwstForj)):
    colors(twomass[1], twomass[2], [twomass[2]], magnitudeCalc, jwstForj[hj], magnitudeCalc2, 9)# ('J'-Ks) jwst
    #colors(twomass[1], twomass[2], jwstForks, magnitudeCalc2, jwstForj[hj], magnitudeCalc2, 9)#('J'-'Ks') jwst-jwst
    
for hj in range(0,len(hstForj)):
    colors(twomass[1], twomass[2], [twomass[2]], magnitudeCalc, hstForj[hj], magnitudeCalc, 9)#('J'-Ks) hst
    #colors(twomass[1], twomass[2], jwstForks, magnitudeCalc2, hstForj[hj], magnitudeCalc, 9)#('J'-'Ks') jwst-hst

# %%
#USES MAGNITUDES AND DIFFERENCES, PLOTS ACCORDINGLY
#still need deviations 
def mag_mag_delta(magFuncHst_Jwst, Hst_Jwst, twoMass):
    FGKM = ['F stars','G stars','K stars', 'M stars']
    figfig = plt.figure()
    for theseFilt in range(0,len(Hst_Jwst)):
        
        #amasses all magnitudes across G,K,M-type stars for ea. type of filter
        mtmass = []
        mhmass = []
        mdmass = []
        
        #subplots of mag-mag and the two delta-mag-mag 
        ax1 = plt.subplot(211)
        ax2 = plt.subplot(223)
        ax3 = plt.subplot(224)
        
        for theseStars in range(0,len(FGKMstars)):
            #initializes arrays used in calculating magnitude, will iterate for G, K, M separately 
            mt = []
            mh = []
            md = []
            
            #magnitude calculation for ea. filter and calculating the difference
            magnitwo = magnitudeCalc(twoMass,FGKMstars[theseStars])
            magnihst = magFuncHst_Jwst(Hst_Jwst[theseFilt],FGKMstars[theseStars])
            magnidiff = [magnitwo - magnihst for magnitwo, magnihst in zip(magnitwo,magnihst)] 
            
            #for ea. class of star
            mt.append(magnitwo)
            mh.append(magnihst)
            md.append(magnidiff)
            
            #format needed to analyze linear model 
            mta = np.asarray(mt[0])
            mha = np.asarray(mh[0])
            mda = np.asarray(md[0])
            
            #linear regression in ea. type of filter and diff for ea. class of star
            regsth = np.polyfit(mta,mha,1)
            regstd = np.polyfit(mta,mda,1)
            regshd = np.polyfit(mha,mda,1)
            
            #printing ea. linear regression of mag-mag and both delta-mag-mag functions, for ea. class of star 
            print(str(FGKM[theseStars]) + ' ' + str(twoMass.name) + ' ' + str(Hst_Jwst[theseFilt].name) + ' mag-mag slope, intercept = ' + str(regsth))
            print(str(FGKM[theseStars]) + ' ' + str(twoMass.name) + ' mag-delta slope, intercept = ' + str(regstd))
            print(str(FGKM[theseStars]) + ' ' + str(Hst_Jwst[theseFilt].name) + ' mag-delta slope, intercept = ' + str(regshd))
            
            #masses all magnitudes and diff calculations across all three classes of star 
            
            if(theseStars !=3):
                mtmass.extend(magnitwo)
                mhmass.extend(magnihst)
                mdmass.extend(magnidiff)
            
            
            #iterates so that the markers between G,K,M on ea. graph are diff. Othe graph properties 
            ax1.scatter(mt, mh, s=size[theseStars], marker = markers[theseStars], c=color[theseStars],alpha = 0.23, label=FGKM[theseStars])
            ax2.scatter(mt, md, s=size[theseStars], marker = markers[theseStars], c=color[theseStars],alpha = 0.23)
            ax3.scatter(mh, md, s=size[theseStars], marker = markers[theseStars], c=color[theseStars],alpha = 0.23)
            ax1.set_position([0.15, 0.6, 0.8, 0.4])
            ax2.set_position([0.125, 0.1, 0.36, 0.33])
            ax3.set_position([0.625, 0.1, 0.36, 0.33])
        
        
            
        firstfit = np.polyfit(np.asarray(mtmass),np.asarray(mhmass),1)
        secondfit = np.polyfit(np.asarray(mtmass),np.asarray(mdmass),1)
        thirdfit = np.polyfit(np.asarray(mhmass),np.asarray(mdmass),1)
        zeros1 = np.zeros(len(mtmass))
        zeros1 = zeros1 + firstfit[1] 
        zeros2 = np.zeros(len(mtmass))
        zeros2 = zeros2 + secondfit[1]
        zeros3 = np.zeros(len(mhmass))
        zeros3 = zeros3 + thirdfit[1] 
        
        ax1.plot(np.unique(mtmass), np.poly1d(np.polyfit(np.asarray(mtmass),np.asarray(mhmass),1))(np.unique(mtmass)), label='y=' + str("%.4f" % firstfit[0]) + '*x' + ' + ' + str("%.4f" % firstfit[1]))
        ax1.plot(mtmass,zeros1,label='y = ' + str("%.4f" % firstfit[1]))
        ax2.plot(np.unique(mtmass), np.poly1d(np.polyfit(np.asarray(mtmass),np.asarray(mdmass),1))(np.unique(mtmass)), label='y=' + str("%.4f" % secondfit[0]) + '*x' + ' + ' + str("%.4f" % secondfit[1]))
        ax2.plot(mtmass,zeros2,label='y = ' + str("%.4f" % secondfit[1]))
        ax3.plot(np.unique(mhmass), np.poly1d(np.polyfit(np.asarray(mhmass),np.asarray(mdmass),1))(np.unique(mhmass)), label='y=' + str("%.4f" % thirdfit[0]) + '*x' + ' + ' + str("%.4f" % thirdfit[1]))
        ax3.plot(mhmass,zeros3,label='y = ' + str("%.4f" % thirdfit[1]))
        
        #linear regression for entire graph
        print('')
        print('all spectra ' + str(twoMass.name) + ' ' + str(Hst_Jwst[theseFilt].name) + ' mag-mag slope, intercept = ' + str(np.polyfit(np.asarray(mtmass),np.asarray(mhmass),1)))
        print('all spectra ' + str(twoMass.name) + ' mag-delta slope, intercept = ' + str(np.polyfit(np.asarray(mtmass),np.asarray(mdmass),1)))
        print('all spectra ' + str(Hst_Jwst[theseFilt].name) + ' mag-delta slope, intercept = ' + str(np.polyfit(np.asarray(mhmass),np.asarray(mdmass),1)))
        
        #sets limits so we can see what's going on 
        ax1.set_ylim((min(mhmass)-0.1),(max(mhmass)+0.1))
        ax1.set_xlim((min(mtmass)-0.1),(max(mtmass)+0.1)) 
        ax1.set_xlabel(str(twoMass.name), fontsize=9)
        ax1.set_ylabel(str(Hst_Jwst[theseFilt].name), fontsize=9)
        ax1.legend(loc=8, bbox_to_anchor=(0.5, 0.7), ncol=3, prop={'size': 9})
        ax1.text(median(mtmass), (min(mhmass)-2.5), 'variance of mag. dif.= ' + str("%.4f" % variance(mdmass)), fontsize=9)
        
        ax2.set_ylim((min(mdmass)-0.1),(max(mdmass)+0.1))
        ax2.set_xlim((min(mtmass)-0.1),(max(mtmass)+0.1)) 
        ax2.set_xlabel(str(twoMass.name), fontsize=9)
        ax2.set_ylabel(str(twoMass.name) + ' -- ' + str(Hst_Jwst[theseFilt].name), fontsize=9)
        ax2.legend(loc=9, bbox_to_anchor=(0.5, 1.2), ncol=3, prop={'size': 7})
        
        ax3.set_ylim((min(mdmass)-0.1),(max(mdmass)+0.1))
        ax3.set_xlim((min(mhmass)-0.1),(max(mhmass)+0.1)) 
        ax3.set_xlabel(str(Hst_Jwst[theseFilt].name), fontsize=9)
        ax3.legend(loc=9, bbox_to_anchor=(0.5, 1.2), ncol=3, prop={'size': 7})
        #ax3.text(0.5, -0.01, 'variance = ' + str(variance(mdmass)), fontsize=9)
        #ax3.set_ylabel(str(twoMass.name) + '-' + str(Hst_Jwst[theseFilt].name), fontsize=7) 
        #(commented because it shares axis label w/ the other delta-mag-mag graph)
        
        #creates the figure for ea. hst/jwst filter, across G,K,M stars for specified 2mass filter
        #moves on to next hst/jwst filter only when this set is done 
        pdfgraphing.savefig()
        plt.show()

# %%
pdfgraphing = PdfPages('Mag_color.pdf')
mag_mag_delta(magnitudeCalc,[hstForj[0]],twomass[1])
mag_mag_delta(magnitudeCalc,[hstForj[0]],twoMass_J)
pdfgraphing.close()
pdfgraphic = PdfPages('Color_Color.pdf')
colors(twomass[1], twomass[0], magnitudeCalc, [hstForh[2]], magnitudeCalc, hstForj[0], magnitudeCalc, 9)
colors(twoMass_J, twomass[0], magnitudeCalc, [hstForh[2]], magnitudeCalc, hstForj[0], magnitudeCalc, 9)
pdfgraphic.close()
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# F stars 2MASS_J HST_WFC3_F110W mag-mag slope, intercept = [1.00169658 0.09457183]
# F stars 2MASS_J mag-delta slope, intercept = [-0.00169658 -0.09457183]
# F stars HST_WFC3_F110W mag-delta slope, intercept = [-0.00202702 -0.0928644 ]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# G stars 2MASS_J HST_WFC3_F110W mag-mag slope, intercept = [0.99651881 0.18952929]
# G stars 2MASS_J mag-delta slope, intercept = [ 0.00348119 -0.18952929]
# G stars HST_WFC3_F110W mag-delta slope, intercept = [ 0.00283343 -0.18717387]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# K stars 2MASS_J HST_WFC3_F110W mag-mag slope, intercept = [1.00161129 0.2266576 ]
# K stars 2MASS_J mag-delta slope, intercept = [-0.00161129 -0.2266576 ]
# K stars HST_WFC3_F110W mag-delta slope, intercept = [-0.00185368 -0.22542831]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# M stars 2MASS_J HST_WFC3_F110W mag-mag slope, intercept = [1.0225676  0.30995604]
# M stars 2MASS_J mag-delta slope, intercept = [-0.0225676  -0.30995604]
# M stars HST_WFC3_F110W mag-delta slope, intercept = [-0.02311116 -0.30016248]
#
# all spectra 2MASS_J HST_WFC3_F110W mag-mag slope, intercept = [0.99024472 0.21968578]
# all spectra 2MASS_J mag-delta slope, intercept = [ 0.00975528 -0.21968578]
# all spectra HST_WFC3_F110W mag-delta slope, intercept = [ 0.00859498 -0.21661694]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# F stars 2MASS_J1 HST_WFC3_F110W mag-mag slope, intercept = [1.00168817 0.09467522]
# F stars 2MASS_J1 mag-delta slope, intercept = [-0.00168817 -0.09467522]
# F stars HST_WFC3_F110W mag-delta slope, intercept = [-0.0020205  -0.09295974]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# G stars 2MASS_J1 HST_WFC3_F110W mag-mag slope, intercept = [0.99649848 0.1899114 ]
# G stars 2MASS_J1 mag-delta slope, intercept = [ 0.00350152 -0.1899114 ]
# G stars HST_WFC3_F110W mag-delta slope, intercept = [ 0.00284937 -0.18754048]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# K stars 2MASS_J1 HST_WFC3_F110W mag-mag slope, intercept = [1.00161715 0.22712864]
# K stars 2MASS_J1 mag-delta slope, intercept = [-0.00161715 -0.22712864]
# K stars HST_WFC3_F110W mag-delta slope, intercept = [-0.00186115 -0.22589154]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# M stars 2MASS_J1 HST_WFC3_F110W mag-mag slope, intercept = [1.02259535 0.31047939]
# M stars 2MASS_J1 mag-delta slope, intercept = [-0.02259535 -0.31047939]
# M stars HST_WFC3_F110W mag-delta slope, intercept = [-0.02313947 -0.30066099]
#
# all spectra 2MASS_J1 HST_WFC3_F110W mag-mag slope, intercept = [0.99020718 0.22015192]
# all spectra 2MASS_J1 mag-delta slope, intercept = [ 0.00979282 -0.22015192]
# all spectra HST_WFC3_F110W mag-delta slope, intercept = [ 0.00862507 -0.21706197]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# F stars 2MASS_J - HST_WFC3_F160W 2MASS_J - 2MASS_H color fit = [-0.12459608 -0.03786761]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# G stars 2MASS_J - HST_WFC3_F160W 2MASS_J - 2MASS_H color fit = [-0.03628203 -0.06656247]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# K stars 2MASS_J - HST_WFC3_F160W 2MASS_J - 2MASS_H color fit = [ 0.02693584 -0.09535395]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# M stars 2MASS_J - HST_WFC3_F160W 2MASS_J - 2MASS_H color fit = [ 0.04635579 -0.10952544]
#
# all spectra 2MASS_J - HST_WFC3_F160W2MASS_J - 2MASS_H color fit = [-0.01424182 -0.06933076]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# F stars 2MASS_J1 - HST_WFC3_F160W 2MASS_J1 - 2MASS_H color fit = [-0.12547315 -0.03774376]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# G stars 2MASS_J1 - HST_WFC3_F160W 2MASS_J1 - 2MASS_H color fit = [-0.03732835 -0.06638569]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# K stars 2MASS_J1 - HST_WFC3_F160W 2MASS_J1 - 2MASS_H color fit = [ 0.02621191 -0.09532609]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# M stars 2MASS_J1 - HST_WFC3_F160W 2MASS_J1 - 2MASS_H color fit = [ 0.04575276 -0.10949046]
#
# all spectra 2MASS_J1 - HST_WFC3_F160W2MASS_J1 - 2MASS_H color fit = [-0.01512862 -0.06921083]

# %%
pdfgraphing = PdfPages('newGraphs1.pdf')
mag_mag_delta(magnitudeCalc,[hstForj[0]],twomass[1])
mag_mag_delta(magnitudeCalc,[hstForh[2]],twomass[0])
pdfgraphing.close()
# Out:
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# F stars 2MASS_J HST_WFC3_F110W mag-mag slope, intercept = [1.00169658 0.09457183]
# F stars 2MASS_J mag-delta slope, intercept = [-0.00169658 -0.09457183]
# F stars HST_WFC3_F110W mag-delta slope, intercept = [-0.00202702 -0.0928644 ]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# G stars 2MASS_J HST_WFC3_F110W mag-mag slope, intercept = [0.99651881 0.18952929]
# G stars 2MASS_J mag-delta slope, intercept = [ 0.00348119 -0.18952929]
# G stars HST_WFC3_F110W mag-delta slope, intercept = [ 0.00283343 -0.18717387]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# K stars 2MASS_J HST_WFC3_F110W mag-mag slope, intercept = [1.00161129 0.2266576 ]
# K stars 2MASS_J mag-delta slope, intercept = [-0.00161129 -0.2266576 ]
# K stars HST_WFC3_F110W mag-delta slope, intercept = [-0.00185368 -0.22542831]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# M stars 2MASS_J HST_WFC3_F110W mag-mag slope, intercept = [1.0225676  0.30995604]
# M stars 2MASS_J mag-delta slope, intercept = [-0.0225676  -0.30995604]
# M stars HST_WFC3_F110W mag-delta slope, intercept = [-0.02311116 -0.30016248]
#
# all spectra 2MASS_J HST_WFC3_F110W mag-mag slope, intercept = [0.99024472 0.21968578]
# all spectra 2MASS_J mag-delta slope, intercept = [ 0.00975528 -0.21968578]
# all spectra HST_WFC3_F110W mag-delta slope, intercept = [ 0.00859498 -0.21661694]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# F stars 2MASS_H HST_WFC3_F160W mag-mag slope, intercept = [0.99804402 0.04484366]
# F stars 2MASS_H mag-delta slope, intercept = [ 0.00195598 -0.04484366]
# F stars HST_WFC3_F160W mag-delta slope, intercept = [ 0.00181998 -0.04432307]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# G stars 2MASS_H HST_WFC3_F160W mag-mag slope, intercept = [0.9911985  0.12562272]
# G stars 2MASS_H mag-delta slope, intercept = [ 0.0088015  -0.12562272]
# G stars HST_WFC3_F160W mag-delta slope, intercept = [ 0.00848799 -0.12516012]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# K stars 2MASS_H HST_WFC3_F160W mag-mag slope, intercept = [0.99805444 0.16045157]
# K stars 2MASS_H mag-delta slope, intercept = [ 0.00194556 -0.16045157]
# K stars HST_WFC3_F160W mag-delta slope, intercept = [ 0.0016865  -0.16003997]
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# Warning: assuming units are consistent
# M stars 2MASS_H HST_WFC3_F160W mag-mag slope, intercept = [1.02958427 0.25706059]
# M stars 2MASS_H mag-delta slope, intercept = [-0.02958427 -0.25706059]
# M stars HST_WFC3_F160W mag-delta slope, intercept = [-0.03002171 -0.24736082]
# all spectra 2MASS_H HST_WFC3_F160W mag-mag slope, intercept = [0.98513606 0.15612105]
# all spectra 2MASS_H mag-delta slope, intercept = [ 0.01486394 -0.15612105]
# all spectra HST_WFC3_F160W mag-delta slope, intercept = [ 0.01424055 -0.15543574]

# %%
#ALL POSSIBLE CALLS FOR GETTING MAG-MAG AND MAG-DELTA GRAPHS 
mag_mag_delta(magnitudeCalc2,jwstForh,twomass[0])
mag_mag_delta(magnitudeCalc2,jwstForj,twomass[1])
mag_mag_delta(magnitudeCalc2,jwstForks,twomass[2])
mag_mag_delta(magnitudeCalc,hstForh,twomass[0])
mag_mag_delta(magnitudeCalc,hstForj,twomass[1])

# %%
pdfgraphs.close()

# %%
#'#532f53','#2c5349','#3f532a','#532821'
pdfnew = PdfPages('Filter_star_overlay.pdf')

chara = 'JWST'
colo = ['#144853','#0f1953','#53134f','#531411']
fcol = ['#ee942a','#ee522a','#ee2864','#ee43ca','#be39ee','#6b20ee']

def overlaps(twoma, tLike, star): #add star later
    for st in range(0,len(star)):
        xx, yy = txtfile(star[st])
        xx = xx * 10e3
        yy = yy / max(yy)
        plt.plot(xx,yy,linewidth=1,color=colo[st],label=str(re.sub('star.txt', '', str(star[st]))))
    plt.plot(np.asarray(twoma.wavelength),twoma.transmit,color = fcol[5],linewidth=5,label=twoma.name)
    for tL in range(0,len(tLike)):
        wa = np.asarray(tLike[tL].wavelength)
        if re.search(chara,tLike[tL].name):
            wa = wa * 10e3        
        plt.plot(wa,tLike[tL].transmit,color=fcol[tL],label=tLike[tL].name)
        plt.legend(loc='upper right', prop={'size': 7})
        plt.title(str(twoma.name)+ ' and comparable filters')
        plt.ylabel('transmission')
        plt.xlabel('wavelength (A)')
    plt.xlim(5000,30000)
    #pdfnew.savefig()
    plt.show()

# %%
overlaps(twomass[0],Forh, [Fstars[0],Gstars[0],Kstars[0],Mstars[0]]) #seems like most/all F stars will work 
overlaps(twomass[1],Forj,[Fstars[0],Gstars[0],Kstars[0],Mstars[0]])
overlaps(twomass[2],jwstForks,[Fstars[0],Gstars[0],Kstars[0],Mstars[0]])

pdfnew.close()

# %%
overlaps(twomass[1],[Forj[0]], [Fstars[0],Gstars[0],Kstars[0],Mstars[0]])

# %%
#test
chara = 'JWST'
for le in range(0,len(composite)):
    wa = np.asarray(composite[le].wavelength)
    if re.search(chara,composite[le].name):
        wa = wa * 10e3        
    plt.plot(wa,composite[le].transmit)
    plt.title(composite[le].name)
    plt.ylabel('transmission')
    plt.xlabel('wavelength (A)')
    plt.show()

# %%
def stars(startypes):
    for st in range(0,len(startypes)):
        xx, yy = txtfile(startypes[st])
        xx = xx * 10e3
        plt.plot(xx,yy,linewidth=1,color=colo[st],label=str(re.sub('star.txt', '', str(startypes[st]))))
    plt.xlim(5000,30000)
    plt.ylabel('flux density (Wm-2um-1)')
    plt.xlabel('wavelength (A)')
    irtf.savefig()
    plt.show()

# %%
irtf = PdfPages('irtf2.pdf')
stars([Fstars[0],Gstars[0],Kstars[0],Mstars[0]])
irtf.close()

# %%
#MAKING FIGURES ON CHECKLIST
#TRANSMISSION VS WAVELENGTH OF ALL 'J' FILTERS W/ 2MASSJ, SAME FOR H AND KS

# %%
for ss in range(0,len(tFarray)):
    print(re.sub('star.txt', '', str(tFarray[ss])))
    for xd in range(0,4):
        print('')

# %%
#EXAMPLE OF MONTE CARLO.   
monte, avg = monteCarlo('M9III_IRAS15060+0947star.txt',15,10)
plt.hist(monte, bins='auto')
#plt.hist(avg, bins ='auto')

# %%
def inputsCalc(filter, wave, flux):
    wave = wave * 10e3 #standardized to A
    flux = flux * 10e-2 #standardized to A^(-1)
    fluxes = filter.get_flux(wave, flux, axis=-1) #for some reason, using fits file data produces nan
    RegMags = -2.5 * np.log10(fluxes) - filter.Vega_zero_mag
    return RegMags

# %%
def monteFiles1(filter,file,rounds):
    magnitudes = []
    wave, mag = txtfile(file)    
    for _ in range (0,rounds):
        monte, avg = monteCarlo(file, len(mag),1)
        newFlux = mag + monte
        magnitude = inputsCalc(filter,wave,newFlux)
        magnitudes.append(magnitude)
    return magnitudes

# %%
theseMags = monteFiles1(composite[0],Gstars[0],1000) #need to loop through filters and spectra
plt.hist(theseMags, bins='auto')

# %%
thesemagsAvg = sum(theseMags)/1000
vari = variance(theseMags)
stde = stdev(theseMags)
print(thesemagsAvg)
print(vari)
print(stde)

# %%
#works in theory but takes an incredibly long time to run 
#need to get the pairings of filters that overlap with certain spectra
for r in range(0,len(composite)):
    for s in range(0,len(GKM)):
        theseMags = monteFiles1(composite[r],GKM[s],1000)
        theseMagsAvg = theseMags/1000
        if np.all(np.isfinite(theseMags)):
            plt.hist(theseMags, bins='auto')
            plt.show()

# %%
#gets zeropts from SOV 
names, fluxdata = datafile('SOV_zero_flux.txt') #provides names and zeropts for filters 
theseFiltersarray = np.asarray(theseFilters)

# %%
#TABLE STUFF BELOW. NOT TO WORRY ABOUT NOW

# %%
#GOAL: DESIGN A TABLE THAT WILL DISPLAY MEAN, STDEV, VARIANCE, CALCULATED FROM PYPHOT AND CALCULATED FROM SOV SITE
#good news: can set up a table from an array so...
    #set up array with row titles 
    #or ignore pre-allocating array and just add a column or row (column more straightforward)
    #NEW METHOD:
        #skip first line by creating blank, set up first column of names and skipping five lines
        #set up colunms with name as filter that it is working on, followed by the values (which should be in order and which should correspond to the spectrum on it at the time of calculation)

# %%
input = open('Spectral_Data.txt', 'r')
outfile = open('Spectral_Data.txt', 'w')

# %%
print((theseFilters))
theseFilters1 = theseFilters[0:6]
theseFilters2 = theseFilters[6:13]
theseFilters3 = theseFilters[13:18]

# %%
for spectra in range(0,len(GKM)):
    for filters in range(0,len(theseFilters)):
        contents = {i[filters].name:[(GKM[spectra], mean, median, stdev)]}

# %%
#my attempt to write in the data that i'm processing here. got the two table labels, but need to sort out formattinig and filling in the data
def WritingAFile(fileNo,spectralArray):
    with open('Spectral_Data' + str(fileNo) + '.txt' , 'w') as the_file:
        for x in range(0,len(spectralArray)): 
            the_file.write('                                          ' + spectralArray[x] + '              ')
        for y in range(0,len(GKM)):
            the_file.write('\n')
            GKM[y] = re.sub('star.txt', '', GKM[y])
            the_file.write(GKM[y])
            the_file.write('\n\n\n')#instead of this, fill lines with mean, stdev, median

# %%
WritingAFile(1,theseFilters1)
WritingAFile(2,theseFilters2)
WritingAFile(3,theseFilters3)
